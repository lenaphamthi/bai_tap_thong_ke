# %% [markdown]
# <a href="https://colab.research.google.com/github/lenaphamthi/bai_tap_thong_ke/blob/main/kiem_dinh_F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kiểm tra F là kiểm tra thống kê, xác định sự bằng nhau của phương sai của hai quần thể bình thường (thử nghiệm được thực hiện khi không biết liệu hai quần thể có cùng phương sai không.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# KIỂM ĐỊNH F
#
# Thay vì xây dựng giả thuyết với giá trị trung bình, người ta có thể xây dựng giả thuyết với phương sai (variance $\sigma^{2}$). Trong trường hợp này, chúng ta sử dụng kiểm định F. Tóm tắt về kiểm định F như sau:
#
# Kiểm định một đuôi:
#
# $$H_{0}: \sigma^{2} = \sigma_{0}^{2} $$
#
# $$H_{a}: \sigma^{2} < \sigma_{0}^{2} (H_{a}: \sigma^{2} > \sigma_{0}^{2})$$
#
# Giá trị thống kê kiểm định:
#
# $$ \chi^{2} = \frac{(n-1)s^{2}}{\sigma_{0}^{2}}$$
#
# Vùng bác bỏ: $\chi^{2} < \chi_{(1 - \alpha)}^{2}$  hoặc $\chi^{2} > \chi_{(1 - \alpha)}^{2}$  khi $H_{a}: \sigma^{2} > \sigma_{0}^{2}$
#
# Ghi chú:
#
# - $\chi^{2}$ - chi-square
# - (n - 1) mức tự do

# %% [markdown]
# Kiểm định 2 đuôi:
#
# $$H_{0}: \sigma^{2} = \sigma_{0}^{2}$$
# $$H_{a}:\sigma^{2} \neq \sigma_{0}^{2} $$
#
# Giá trị thống kê kiểm định:
#
# $$ \chi^{2} = \frac{(n-1)s^{2}}{\sigma_{0}^{2}}$$
#
# Vùng bác bỏ: $\chi^{2} < \chi_{(1 - \alpha/2)}^{2}$  hoặc $\chi^{2} > \chi_{(\alpha/2)}^{2}$
# Ghi chú:
#
# - $\chi^{2}$ - chi-square
# - (n - 1) mức tự do

# %% [markdown]
# THỰC HÀNH KIỂM ĐỊNH F
#
# Bước 1: Sinh ngẫu nhiên số liệu
#
# Bước 2: Xây dựng giả thuyết
#
# Bước 3: Kiểm định Bartlett

# %%
import numpy as np
import pandas as pd
import random
from scipy import stats
from statsmodels.stats.weightstats import ztest
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Sinh ngẫu nhiên 1000 mẫu tuân theo phân phối chuẩn có trung bình mẫu là 7.5 và độ lệch chuẩn là 0.25
mean_1 = 7.5
std_1 = 0.25
N_1 = 1000
samples_1 = np.random.normal(mean_1, std_1, N_1)

# %%
#In ra 10 phần tử đầu tiên
print(samples_1[:10])
# Out:
# [7.56972606 7.5846344  7.33158137 7.74958675 6.90307587 8.00185318
#  7.42713347 7.74169288 7.72075042 7.57714713]

# %%
#Sinh ngẫu nhiên 900 mẫu tuân theo phân phối chuẩn có trung bình mẫu là 7 và độ lệch chuẩn là 0.2
mean_2= 7
std_2 = 0.2
N_2 = 900
samples_2 = np.random.normal(mean_2, std_2, N_2)

# %%
#In ra 10 phần tử đầu tiên
print(samples_2[:10])
# Out:
# [6.93304032 6.92546106 6.90924755 7.14933203 6.92258194 7.16393108
#  6.86055003 7.25055052 6.91431871 7.27533443]

# %% [markdown]
# Xây dựng giả thuyết:
# $$H_{0}: \sigma_{1}^{2} = \sigma_{2}^{2}$$
# $$H_{a}: \sigma_{1}^{2} \neq \sigma_{2}^{2}$$

# %%
#Kiểm định Bartlett
stat_value, p_value = stats.bartlett(samples_1, samples_2)
print("Stat value: ", stat_value, "; p-value: ", p_value)
# Out:
# Stat value:  47.286719212063026 ; p-value:  6.132632380532056e-12

# %%
alpha = 0.05
if(p_value <  alpha):
  print("Có bằng chứng để bác bỏ giả thuyết H0")
else:
  print("Chưa có bằng chứng để bác bỏ giả thuyết H0")
# Out:
# Có bằng chứng để bác bỏ giả thuyết H0

# %% [markdown]
# BÀI TẬP
#
# Bạn hãy thử viết code tiến hành kiểm định F 1 đuôi?
#
# Gợi ý: Thử tìm kiếm ví dụ về kiểm dịnh F 1 đuôi trong ngôn ngữ lập trình Python & R để nhận thấy sự khác biệt.

# %% [markdown]
# Kiểm định một đuôi:
#
# $$H_{0}: \sigma^{2} = \sigma_{0}^{2} $$
#
# $$H_{a}: \sigma^{2} < \sigma_{0}^{2}$$

# %%
#Sinh ngẫu nhiên 1000 mẫu tuân theo phân phối chuẩn có trung bình mẫu 25.4 là và độ lệch chuẩn là 2.5 
mean_1 = 25.4 
std_1 = 2.5 
N_1 = 100
samples_1 = np.random.normal(mean_1, std_1, N_1)

# %%
#in ra 10 phần tử đầu tiên
print(samples_1)
# Out:
# [24.46136247 28.27153591 26.74530224 26.38108655 26.59370575 28.07098649
#  25.17479429 22.83781369 28.18080552 26.06888798 24.4511181  25.74466498
#  24.06591946 25.43267989 26.19728369 26.66948401 25.15833526 28.40539755
#  26.39918107 27.75064731 26.58472487 26.13200669 22.24673388 24.10491417
#  23.27621649 24.87195239 21.79825935 27.74567924 30.74596675 27.45650904
#  25.99464488 24.21957035 24.85392024 24.06799571 25.09226193 26.17559655
#  28.38317402 29.63804857 28.37205153 26.35147825 23.52773356 26.12955191
#  26.49959685 23.76035465 29.15757017 28.16399845 23.0867099  26.37863612
#  27.80557598 23.88790586 26.83566958 25.55416773 23.74549937 23.20583477
#  27.22702595 22.95738643 27.85463586 25.60565885 25.13445629 28.12201103
#  30.71586007 24.98117072 24.93746658 24.96151186 25.0158677  28.23354652
#  26.44993374 24.54019968 29.88222114 27.62625933 21.6501774  29.0824432
#  27.47839951 25.7921334  24.52869186 24.90372516 25.34376051 24.63228539
# ...

# %%
#Sinh ngẫu nhiên 900 mẫu tuân theo phân phối chuẩn có trung bình mẫu là 22.4  và độ lệch chuẩn là 
mean_2= 24.1 
std_2 = 2.3 
N_2 = 900
samples_2 = np.random.normal(mean_2, std_2, N_2)

# %%
#in ra 10 phần tử đầu
print(samples_2)
# Out:
# [22.8729608  20.14638359 24.6913976  22.2130163  21.37721619 24.06218037
#  20.14212088 26.52413142 27.92761714 26.70988104 25.16835899 24.07212046
#  20.36566918 24.76476421 24.30901273 26.25503883 24.59745264 24.91741618
#  24.70529205 25.05344494 24.44602103 24.91162316 21.71171391 22.20350544
#  24.71595994 21.99456348 26.28758284 23.05030406 19.78543218 23.7569777
#  24.4639896  19.40138395 20.27261446 24.32875203 22.77577782 23.46367875
#  25.34174409 26.20708675 19.95848846 26.21975645 24.9424292  25.45020491
#  25.65833919 25.26758441 23.93796504 24.5428936  24.40270177 31.0695115
#  21.22800672 24.06128659 27.12222413 24.13460958 24.91070081 22.80348273
#  26.64059357 25.7873999  22.62700887 28.16694165 24.22945811 24.45943504
#  24.88237329 23.39725311 25.46517289 26.68590671 22.99639056 27.47773998
#  19.83036437 22.90738075 25.71141212 26.82627825 23.09809663 23.74974566
#  26.18430459 23.64437491 27.00510547 25.23535898 19.64115385 28.19994348
# ...

# %%
# Xác định thông số:
alpha = 0.05

# %%
def f_test_1tailed(samples_1, samples_2,y):
    x1 = len(samples_1)-1 
    x2 = len(samples_2) -1 
    f = samples_1.var()/samples_2.var()
    if y == "larger":
      pv = 1 - stats.f.cdf(f, x1, x2)
    elif y == "smaller":
      pv = stats.f.cdf(f, x1, x2) 
    return f, pv
# Out:
# p-value:  0.4599864306508667

# %%
#Kiểm định giả thuyết 
ftest,p_value = f_test_1tailed(samples_1, samples_2, "smaller")
print("p-value: ", p_value)
if(p_value < alpha):
  print("Có bằng chứng để bác bỏ giả thuyết H0")
else:
  print("Chưa có bằng chứng để bác bỏ giả thuyết H0")
# Out:
# p-value:  0.4599864306508667
# Chưa có bằng chứng để bác bỏ giả thuyết H0
